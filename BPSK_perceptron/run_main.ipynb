# %%
# %run main.py
# Out:
# Epoch 0, errors: 1
# Converged at epoch 2
# Final weights: [0.002 0.   ]
# Pure: errors=0, error_rate=0.00%
# Noise: errors=8, error_rate=0.80%
# Phase: errors=0, error_rate=0.00%
# Both: errors=10, error_rate=1.00%
# Fading: errors=0, error_rate=0.00%
# Epoch 0, errors: 1
# Converged at epoch 2
# Final weights: [-0.001  0.   ]
# Pure: errors=0, error_rate=0.00%
# Noise: errors=8, error_rate=0.80%
# Phase: errors=0, error_rate=0.00%
# Both: errors=10, error_rate=1.00%
# Fading: errors=0, error_rate=0.00%
