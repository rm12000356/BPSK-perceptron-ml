# %%
# %run main.py
# Out:
# Stopping early at epoch 146 with MSE 0.0100
# pure error = 0.0000, accuracy = 1.0000
# noise error = 0.3850, accuracy = 0.4800
# phase error = 0.0500, accuracy = 0.9000
# both error = 0.2650, accuracy = 0.6800
# fading error = 0.1750, accuracy = 0.7300
